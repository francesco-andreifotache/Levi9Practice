# %%
import numpy as np

# %%
def exercise_1():
    """
    Select all even numbers from the np  array [1, 2, 3, 4, 5, 6, 7, 8].
    Output: [2, 4, 6, 8]
    """
    a = np.array([1, 2, 3, 4, 5, 6, 7, 8])
    return a[a % 2 == 0]

b = exercise_1()
print(b)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 9
#       5     """
#       6     a = np.array([1, 2, 3, 4, 5, 6, 7, 8])
#       7     return a[a % 2 == 0]
#       8
# ----> 9 b = exercise_1()
#      10 print(b)
#
# Cell In[1], line 6, in exercise_1()
#       2     """
#       3     Select all even numbers from the np  array [1, 2, 3, 4, 5, 6, 7, 8].
#       4     Output: [2, 4, 6, 8]
#       5     """
# ----> 6     a = np.array([1, 2, 3, 4, 5, 6, 7, 8])
#       7     return a[a % 2 == 0]
#
# NameError: name 'np' is not defined
